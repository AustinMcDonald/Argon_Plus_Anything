# %%
import numpy as np 
from tables import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
APA = open_file("Argon_Plus_Anything.h5")

# %%
Percent = ["20.0", "10.0", "1.0", "0.1", "0.01", "0.001", "0.0001"]

# %%
APA.root
# Out:
# / (RootGroup) 'Argon_Plus_Anything'
#   children := ['HELIUM3' (Group), 'HELIUM4' (Group), 'KRYPTON' (Group), 'NEON' (Group), 'XENON' (Group)]

# %%
APA.root.HELIUM3['0.1']
# Out:
# /HELIUM3/0.1 (Group) ''
#   children := ['Drift_Velocity' (Array), 'Drift_Velocity_Error' (Array), 'Long' (Array), 'LongE' (Array), 'Reduced_Field' (Array), 'Trans' (Array), 'TransE' (Array)]

# %%
plt.figure(figsize=(7,7))
plt.title("drift")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.HELIUM3[Per].Reduced_Field.read()
    dz = APA.root.HELIUM3[Per].Drift_Velocity.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

plt.figure(figsize=(7,7))
plt.title("Dl")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.HELIUM3[Per].Reduced_Field.read()
    dz = APA.root.HELIUM3[Per].Long.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

plt.figure(figsize=(7,7))
plt.title("Dt")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.HELIUM3[Per].Reduced_Field.read()
    dz = APA.root.HELIUM3[Per].Trans.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.title("drift")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.HELIUM4[Per].Reduced_Field.read()
    dz = APA.root.HELIUM4[Per].Drift_Velocity.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

plt.figure(figsize=(7,7))
plt.title("Dl")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.HELIUM4[Per].Reduced_Field.read()
    dz = APA.root.HELIUM4[Per].Long.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

plt.figure(figsize=(7,7))
plt.title("Dt")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.HELIUM4[Per].Reduced_Field.read()
    dz = APA.root.HELIUM4[Per].Trans.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.title("drift")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.KRYPTON[Per].Reduced_Field.read()
    dz = APA.root.KRYPTON[Per].Drift_Velocity.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

plt.figure(figsize=(7,7))
plt.title("Dl")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.KRYPTON[Per].Reduced_Field.read()
    dz = APA.root.KRYPTON[Per].Long.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

plt.figure(figsize=(7,7))
plt.title("Dt")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.KRYPTON[Per].Reduced_Field.read()
    dz = APA.root.KRYPTON[Per].Trans.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.title("drift")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.NEON[Per].Reduced_Field.read()
    dz = APA.root.NEON[Per].Drift_Velocity.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

plt.figure(figsize=(7,7))
plt.title("Dl")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.NEON[Per].Reduced_Field.read()
    dz = APA.root.NEON[Per].Long.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

plt.figure(figsize=(7,7))
plt.title("Dt")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.NEON[Per].Reduced_Field.read()
    dz = APA.root.NEON[Per].Trans.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.title("drift")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.XENON[Per].Reduced_Field.read()
    dz = APA.root.XENON[Per].Drift_Velocity.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

plt.figure(figsize=(7,7))
plt.title("Dl")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.XENON[Per].Reduced_Field.read()
    dz = APA.root.XENON[Per].Long.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

plt.figure(figsize=(7,7))
plt.title("Dt")
for x in range(0,len(Percent)):
    Per = Percent[x]
    redu = APA.root.XENON[Per].Reduced_Field.read()
    dz = APA.root.XENON[Per].Trans.read()
    plt.plot(redu,dz,linewidth=2,alpha=0.7, label=Per)
plt.legend(loc="lower right",fontsize=12)
plt.show()

# %%
qqq=9
